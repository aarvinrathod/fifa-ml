# %%
# Import dependencies
import pandas as pd

# %% [markdown]
# ## Creating subset of 30 players to use for dropdown menus
# * following same proc as original data cleaning EXCEPT: keeping FullName & Nationality to use in dropdown

# %%
# Load File
path = "Resources/players_fifa22.csv"
df = pd.read_csv(path)

# %%
# Dropping all Goal Keepers
df = df[(df["BestPosition"] != "GK")]

# %%
# Changing High Medium and Low Values
df = df.replace(["High", "Medium", "Low"], [2,1,0])

# %%
df
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   34     170
# 1      188545     R. Lewandowski            Robert Lewandowski   32     185
# 2       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   36     187
# 3      231747          K. Mbappé                 Kylian Mbappé   22     182
# 5      192985       K. De Bruyne               Kevin De Bruyne   30     181
# ...       ...                ...                           ...  ...     ...
# 19253  260474       Kim Bong Soo                  Bong Soo Kim   21     183
# 19255  262759           S. Black                 Stephen Black   19     180
# 19257  261985         Yang Haoyu                    Haoyu Yang   20     183
# 19258  261977           He Siwei                      Siwei He   20     174
# 19259  261932      Chen Guoliang                 Guoliang Chen   22     186
#
#        Weight                                          PhotoUrl  \
# 0          72  https://cdn.sofifa.com/players/158/023/22_60.png
# 1          81  https://cdn.sofifa.com/players/188/545/22_60.png
# 2          83  https://cdn.sofifa.com/players/020/801/22_60.png
# 3          73  https://cdn.sofifa.com/players/231/747/22_60.png
# 5          70  https://cdn.sofifa.com/players/192/985/22_60.png
# ...       ...                                               ...
# 19253      78  https://cdn.sofifa.com/players/260/474/22_60.png
# 19255      75  https://cdn.sofifa.com/players/262/759/22_60.png
# 19257      77  https://cdn.sofifa.com/players/261/985/22_60.png
# 19258      69  https://cdn.sofifa.com/players/261/977/22_60.png
# 19259      70  https://cdn.sofifa.com/players/261/932/22_60.png
#
#                Nationality  Overall  Potential  ...  LMRating  CMRating  \
# 0                Argentina       93         93  ...        93        90
# 1                   Poland       92         92  ...        87        83
# 2                 Portugal       91         91  ...        89        81
# 3                   France       91         95  ...        92        84
# 5                  Belgium       91         91  ...        91        91
# ...                    ...      ...        ...  ...       ...       ...
# 19253       Korea Republic       48         57  ...        49        50
# 19255  Republic of Ireland       48         62  ...        36        35
# 19257             China PR       48         55  ...        36        35
# 19258             China PR       48         58  ...        38        37
# 19259             China PR       48         53  ...        35        35
#
#        RMRating LWBRating CDMRating RWBRating  LBRating  CBRating  RBRating  \
# 0            93        69        67        69        64        53        64
# 1            87        67        69        67        64        63        64
# 2            89        66        62        66        63        56        63
# 3            92        70        66        70        66        57        66
# 5            91        82        83        82        78        72        78
# ...         ...       ...       ...       ...       ...       ...       ...
# 19253        49        50        52        50        50        51        50
# 19255        36        44        43        44        47        50        47
# 19257        36        46        45        46        48        50        48
# 19258        38        46        45        46        49        50        49
# 19259        35        46        44        46        48        50        48
#
#       GKRating
# 0           22
# 1           22
# 2           23
# 3           21
# 10812     185      78  https://cdn.sofifa.com/players/258/777/22_60.png
# 12436     180      70  https://cdn.sofifa.com/players/257/415/22_60.png
# 14967     175      72  https://cdn.sofifa.com/players/261/555/22_60.png
# 8029      178      73  https://cdn.sofifa.com/players/213/644/22_60.png
# 8910      177      70  https://cdn.sofifa.com/players/245/855/22_60.png
# 15221     180      68  https://cdn.sofifa.com/players/243/866/22_60.png
# 16026     189      75  https://cdn.sofifa.com/players/235/479/22_60.png
# 12582     183      78  https://cdn.sofifa.com/players/239/553/22_60.png
# 18389     176      75  https://cdn.sofifa.com/players/248/242/22_60.png
# 10145     188      86  https://cdn.sofifa.com/players/244/284/22_60.png
# 17495     191      77  https://cdn.sofifa.com/players/261/507/22_60.png
# 16954     172      65  https://cdn.sofifa.com/players/253/309/22_60.png
# 3179      178      72  https://cdn.sofifa.com/players/233/169/22_60.png
# 11436     175      55  https://cdn.sofifa.com/players/260/415/22_60.png
# 10919     178      77  https://cdn.sofifa.com/players/238/519/22_60.png
# 4461      172      69  https://cdn.sofifa.com/players/230/257/22_60.png
# 16110     185      75  https://cdn.sofifa.com/players/243/042/22_60.png
#
#                   Nationality  Overall  Potential  ...  LMRating  CMRating  \
# 14578                Colombia       61         72  ...        56        53
# 4252                Argentina       71         76  ...        51        53
# 10877                 Denmark       65         65  ...        65        65
# 4920                    Japan       70         73  ...        52        56
# 8362                   Mexico       67         68  ...        49        56
# 8024              Switzerland       67         67  ...        48        56
# 10575                  France       65         78  ...        61        63
# 330                   England       81         85  ...        77        69
# 10002                 England       65         82  ...        65        60
# 1740   Bosnia and Herzegovina       75         75  ...        73        72
# 17491                China PR       57         57  ...        57        57
# 11643                   Italy       64         64  ...        64        64
# 129                   England       84         86  ...        80        80
# 10812                  Turkey       65         71  ...        45        48
# 12436        Northern Ireland       63         66  ...        64        58
# 14967                 Bolivia       61         78  ...        59        56
# 8029                  Germany       67         67  ...        62        62
# 8910                   France       66         72  ...        67        67
# 15221                 Denmark       61         71  ...        60        59
# 16026            Saudi Arabia       59         60  ...        52        50
# 12582                 England       63         74  ...        67        65
# 18389            Saudi Arabia       54         63  ...        40        41
# 10145                  France       65         71  ...        51        51
# 17495               Venezuela       57         76  ...        43        47
# 16954                 Uruguay       58         71  ...        60        55
# 3179                    Japan       72         72  ...        69        69
# 11436                   Italy       64         81  ...        64        57
# 10919            Saudi Arabia       65         69  ...        65        59
# 4461                   Brazil       71         71  ...        71        71
# 16110                 Germany       59         69  ...        44        45
#
#        RMRating LWBRating CDMRating RWBRating  LBRating  CBRating  RBRating  \
# 14578        56        61        58        61        61        59        61
# 4252         51        62        65        62        65        73        65
# 10877        65        59        58        59        57        53        57
# 4920         52        65        68        65        67        72        67
# 8362         49        60        65        60        62        68        62
# 8024         48        58        65        58        60        67        60
# 10575        61        63        66        63        64        66        64
# 330          77        61        58        61        59        57        59
# 10002        65        52        49        52        49        44        49
# 1740         73        74        74        74        74        75        74
# 17491        57        57        57        57        57        57        57
# 11643        64        64        64        64        63        60        63
# 129          80        83        82        83        83        83        83
# 10812        45        59        60        59        62        67        62
# 12436        64        50        46        50        47        39        47
# 14967        59        61        59        61        61        60        61
# 8029         62        67        67        67        67        67        67
# 8910         67        62        62        62        60        58        60
# 15221        60        62        60        62        61        57        61
# 16026        52        58        56        58        59        60        59
# 12582        67        63        63        63        62        59        62
# 18389        40        51        50        51        53        56        53
# 10145        51        62        61        62        64        67        64
# 17495        43        53        56        53        56        59        56
# 16954        60        48        45        48        45        37        45
# 3179         69        72        71        72        72        70        72
# 11436        64        51        47        51        49        41        49
# 10919        65        65        61        65        65        64        65
# 4461         71        65        65        65        63        59        63
# 16110        44        53        54        53        55        61        55
#
#       GKRating
# 14578       16
# 4252        18
# 10877       16
# 4920        19
# 8362        18
# 8024        18
# 10575       17
# 330         20
# 10002       18
# 1740        19
# 17491       19
# 11643       20
# 129         19
# 10812       16
# 12436       17
# 14967       18
# 8029        19
# 8910        18
# 15221       15
# 16026       16
# 12582       16
# 18389       15
# 10145       19
# 17495       16
# 16954       17
# 3179        19
# 11436       17
# 10919       16
# 4461        19
# 16110       15
#
# [30 rows x 90 columns]

# %%
# Create List of Columns to drop
columns_to_drop = ["ID","Name","PhotoUrl","Potential","Growth","TotalStats",
                    "BaseStats","Positions","BestPosition","Club","ClubPosition","ContractUntil","ClubNumber",
                    "ClubJoined","OnLoad","NationalTeam","NationalPosition","NationalNumber", "IntReputation",
                    "PreferredFoot",'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
                    'STRating', 'LWRating', 'LFRating', 'CFRating', 'RFRating', 'RWRating',
                    'CAMRating', 'LMRating', 'CMRating', 'RMRating', 'LWBRating',
                    'CDMRating', 'RWBRating', 'LBRating', 'CBRating', 'RBRating',
                    'GKRating']

# Drop Columns
df_random_sample = df_random_sample.drop(columns=columns_to_drop)

# %%
df_random_sample.columns
# Out:
# Index(['FullName', 'Age', 'Height', 'Weight', 'Nationality', 'Overall',
#        'ValueEUR', 'WageEUR', 'ReleaseClause', 'WeakFoot', 'SkillMoves',
#        'AttackingWorkRate', 'DefensiveWorkRate', 'PaceTotal', 'ShootingTotal',
#        'PassingTotal', 'DribblingTotal', 'DefendingTotal', 'PhysicalityTotal',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle'],
#       dtype='object')

# %%
# Dropping higly co-relateed columns
drop_columns = ["Finishing","Dribbling",'Acceleration','SprintSpeed',"StandingTackle",
                'Marking', 'StandingTackle', 'SlidingTackle',"Reactions"]

#Create new Dataframe
df_random_sample = df_random_sample.drop(columns=drop_columns)
# Drop all null values
df_random_sample=df_random_sample.dropna()
# Save new csv
df_random_sample.to_json('Resources/FIFA_random_sample.json')
